# %% [markdown]
# MiniProject 1:
# Today's project is actually a very common interview question, which revolves around a childhood
# counting game called Fizz Buzz.

# %%
previous = " "   

for number in range(1, 101):

    if number % 3 == 0 and number % 5 == 0:
        current = "Fizz Buzz"

    elif number % 3 == 0:
        current = "Fizz"

    elif number % 5 == 0:
        current = "Buzz"

    else:
        current = number

    print(f"Current: {current} | Previous: {previous}")

    previous = current
# Out:
# Current: 1 | Previous:
# Current: 2 | Previous: 1
# Current: Fizz | Previous: 2
# Current: 4 | Previous: Fizz
# Current: Buzz | Previous: 4
# Current: Fizz | Previous: Buzz
# Current: 7 | Previous: Fizz
# Current: 8 | Previous: 7
# Current: Fizz | Previous: 8
# Current: Buzz | Previous: Fizz
# Current: 11 | Previous: Buzz
# Current: Fizz | Previous: 11
# Current: 13 | Previous: Fizz
# Current: 14 | Previous: 13
# Current: Fizz Buzz | Previous: 14
# Current: 16 | Previous: Fizz Buzz
# Current: 17 | Previous: 16
# Current: Fizz | Previous: 17
# Current: 19 | Previous: Fizz
# Current: Buzz | Previous: 19
# Current: Fizz | Previous: Buzz
# Current: 22 | Previous: Fizz
# Current: 23 | Previous: 22
# Current: Fizz | Previous: 23
# Current: Buzz | Previous: Fizz
# Current: 26 | Previous: Buzz
# Current: Fizz | Previous: 26
# Current: 28 | Previous: Fizz
# Current: 29 | Previous: 28
# Current: Fizz Buzz | Previous: 29
# Current: 31 | Previous: Fizz Buzz
# Current: 32 | Previous: 31
# Current: Fizz | Previous: 32
# Current: 34 | Previous: Fizz
# Current: Buzz | Previous: 34
# Current: Fizz | Previous: Buzz
# Current: 37 | Previous: Fizz
# Current: 38 | Previous: 37
# Current: Fizz | Previous: 38
# Current: Buzz | Previous: Fizz
# Current: 41 | Previous: Buzz
# Current: Fizz | Previous: 41
# Current: 43 | Previous: Fizz
# Current: 44 | Previous: 43
# Current: Fizz Buzz | Previous: 44
# Current: 46 | Previous: Fizz Buzz
# Current: 47 | Previous: 46
# Current: Fizz | Previous: 47
# Current: 49 | Previous: Fizz
# Current: Buzz | Previous: 49
# Current: Fizz | Previous: Buzz
# Current: 52 | Previous: Fizz
# Current: 53 | Previous: 52
# Current: Fizz | Previous: 53
# Current: Buzz | Previous: Fizz
# Current: 56 | Previous: Buzz
# Current: Fizz | Previous: 56
# Current: 58 | Previous: Fizz
# Current: 59 | Previous: 58
# Current: Fizz Buzz | Previous: 59
# Current: 61 | Previous: Fizz Buzz
# Current: 62 | Previous: 61
# Current: Fizz | Previous: 62
# Current: 64 | Previous: Fizz
# Current: Buzz | Previous: 64
# Current: Fizz | Previous: Buzz
# Current: 67 | Previous: Fizz
# Current: 68 | Previous: 67
# Current: Fizz | Previous: 68
# Current: Buzz | Previous: Fizz
# Current: 71 | Previous: Buzz
# Current: Fizz | Previous: 71
# Current: 73 | Previous: Fizz
# Current: 74 | Previous: 73
# Current: Fizz Buzz | Previous: 74
# Current: 76 | Previous: Fizz Buzz
# Current: 77 | Previous: 76
# Current: Fizz | Previous: 77
# Current: 79 | Previous: Fizz
# Current: Buzz | Previous: 79
# Current: Fizz | Previous: Buzz
# Current: 82 | Previous: Fizz
# Current: 83 | Previous: 82
# Current: Fizz | Previous: 83
# Current: Buzz | Previous: Fizz
# Current: 86 | Previous: Buzz
# Current: Fizz | Previous: 86
# Current: 88 | Previous: Fizz
# Current: 89 | Previous: 88
# Current: Fizz Buzz | Previous: 89
# Current: 91 | Previous: Fizz Buzz
# Current: 92 | Previous: 91
# Current: Fizz | Previous: 92
# Current: 94 | Previous: Fizz
# Current: Buzz | Previous: 94
# Current: Fizz | Previous: Buzz
# Current: 97 | Previous: Fizz
# Current: 98 | Previous: 97
# Current: Fizz | Previous: 98
# Current: Buzz | Previous: Fizz

# %% [markdown]
# MiniProject 2
# In particular we're going to finding the average budget of the films in our data set, and we're going to
# identify high budget films that exceed the average budget we calculate.

# %%
movies = [
    ("Eternal Sunshine of the Spotless Mind", 20000000),
    ("Memento", 9000000),
    ("Requiem for a Dream", 4500000),
    ("Pirates of the Caribbean: On Stranger Tides", 379000000),
    ("Avengers: Age of Ultron", 365000000),
    ("Avengers: Endgame", 356000000),
    ("Incredibles 2", 200000000)
]

#average budget
total = 0

for movie in movies:
    total = total + movie[1]

average = total / len(movies)
print(f"Average budget: {average}")

#movies above average
count = 0

for movie in movies:
    if movie[1] > average:
        diff = movie[1] - average
        print(f"{movie[0]} is above average by {diff}")
        count = count + 1

print(f"Number of movies above average: {count}")
# Out:
# Average budget: 190500000.0
# Pirates of the Caribbean: On Stranger Tides is above average by 188500000.0
# Avengers: Age of Ultron is above average by 174500000.0
# Avengers: Endgame is above average by 165500000.0
# Incredibles 2 is above average by 9500000.0
# Number of movies above average: 4
